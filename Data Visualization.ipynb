# %% [markdown]
# # DATA VISUALIZATION

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set(style="darkgrid")

# LOADING 2015 Data ########################################################################

cohort4_2015 = pd.read_csv("MAIN_DATA/2015/Cohort4y.csv")
cohort5_2015 = pd.read_csv("MAIN_DATA/2015/Cohort5y.csv")
cohort6_2015 = pd.read_csv("MAIN_DATA/2015/Cohort6y.csv")
cohort4nA_2015 = pd.read_csv("MAIN_DATA/2015/Cohort4ynAug.csv")


# LOADING 2016 Data ########################################################################

cohort4_2016 = pd.read_csv("MAIN_DATA/2016/Cohort4y.csv")
cohort5_2016 = pd.read_csv("MAIN_DATA/2016/Cohort5y.csv")
cohort6_2016 = pd.read_csv("MAIN_DATA/2016/Cohort6y.csv")
cohort4nA_2016 = pd.read_csv("MAIN_DATA/2016/Cohort4ynAug.csv")


# GET ALL STUDENTS
cohort4_2016_ALL = cohort4_2016.loc[cohort4_2016['SUBGROUP_NAME']== "All Students"]
cohort4_2016_ALL["Range"] = cohort4_2016_ALL["Adjust Gross Income"]/cohort4_2016_ALL["pop"]
# Out:
# /home/mango/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ax = sns.scatterplot(x="GRAD_PCT", y="Range", data=cohort4_2016_ALL)

# %%
cohort4_2016_ALL
# Out:
#      Unnamed: 0  Zip Code                                    District Name  \
# 0             1     14202                     BUFFALO CITY SCHOOL DISTRICT
# 17           11     14212     CHEEKTOWAGA-SLOAN UNION FREE SCHOOL DISTRICT
# 31           17     14218                  LACKAWANNA CITY SCHOOL DISTRICT
# 45           22     14223     KENMORE-TONAWANDA UNION FREE SCHOOL DISTRICT
# 61           23     14224              WEST SENECA CENTRAL SCHOOL DISTRICT
# 77           24     14225              CHEEKTOWAGA CENTRAL SCHOOL DISTRICT
# 92           24     14225  CHEEKTOWAGA-MARYVALE UNION FREE SCHOOL DISTRICT
# 107          24     14225        CLEVELAND HILL UNION FREE SCHOOL DISTRICT
# 121          25     14226                  AMHERST CENTRAL SCHOOL DISTRICT
# 137          27     14228               SWEET HOME CENTRAL SCHOOL DISTRICT
#
#     SUBGROUP_NAME ENROLL_CNT GRAD_CNT GRAD_PCT  \
# 0    All Students       2357     1455      62%
# 17   All Students        111       93      84%
# 31   All Students        112       77      69%
# 45   All Students        601      529      88%
# 61   All Students        550      487      89%
# 77   All Students        184      152      83%
# 92   All Students        211      179      85%
# 107  All Students         93       82      88%
# 121  All Students        218      198      91%
# 137  All Students        277      234      84%
#
#                         MEMBERSHIP_DESC  Zip +4  Dependents  \
# 0    2012 Total Cohort - 4 Year Outcome  3375.0       520.0
# 17   2012 Total Cohort - 4 Year Outcome  2295.0      3550.0
# 31   2012 Total Cohort - 4 Year Outcome  3595.0      5090.0
# 45   2012 Total Cohort - 4 Year Outcome  1196.0      5340.0
# 61   2012 Total Cohort - 4 Year Outcome  4098.0      9300.0
# 77   2012 Total Cohort - 4 Year Outcome  5170.0      7700.0
# 92   2012 Total Cohort - 4 Year Outcome  2386.0      7700.0
# 107  2012 Total Cohort - 4 Year Outcome  1599.0      7700.0
# 121  2012 Total Cohort - 4 Year Outcome  4330.0      7130.0
# 137  2012 Total Cohort - 4 Year Outcome  3399.0      4770.0
#
#      Adjust Gross Income  Salaries and Wage       Range      pop
# 0               385944.0           106297.0  112.882129   3419.0
# 17              119830.0           100158.0   11.292998  10611.0
# 31              339570.0           261170.0   17.955266  18912.0
# 45              677371.0           500343.0   29.309463  23111.0
# 61             1261685.0           913023.0   31.030128  40660.0
# 77              781098.0           619651.0   23.475431  33273.0
# 92              781098.0           619651.0   23.475431  33273.0
# 107             781098.0           619651.0   23.475431  33273.0
# 121            1196156.0           744559.0   40.666213  29414.0
# 137             606568.0           431255.0   28.169229  21533.0
