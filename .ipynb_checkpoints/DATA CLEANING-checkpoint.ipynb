# %% [markdown]
# # DATA CLEANING
#
# For this week I will be cleaning up the data that I received from various souses. The good this is that majority of the data for schools are very clean to begin with. This means that my data cleaning can be kept to a minimum.
#
# The data sets I will be using are as follows:
#
#     IRS's Income by zipcode
#     Graduation rates by school
#     School Zip Code
#
# The school's Zip Code file did not come in a CSV and to import it to a CSV I took to excel and created a CSV version of the excel file.

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set(style="darkgrid")


# HERE I IMPORTED DATA FROM NYSTATE DATA FOR
# GRADUATION RATES BY SCHOOL (NEED TO FIND A WAY TO ASSIGN ZIP CODE TO THEM)
grad2016 = pd.read_csv('SCHOOL_DATA/GRAD_RATE_AND_OUTCOMES_2016.csv', error_bad_lines = False)
grad2015 = pd.read_csv('SCHOOL_DATA/GRAD_RATE_AND_OUTCOMES_2015.csv' , error_bad_lines = False)

schoolZip = pd.read_csv('ny.csv', error_bad_lines = False)

population = pd.read_csv('pop-by-zip-code.csv')
cityZip = pd.read_csv('cityZip.csv')

grad2015School = grad2015.loc[grad2015['AGGREGATION_TYPE'] == 'District']
grad2016School = grad2016.loc[grad2016['AGGREGATION_TYPE'] == 'District']

grad2015Schools = grad2015.loc[grad2015['AGGREGATION_TYPE'] == 'School']
grad2016Schools = grad2016.loc[grad2016['AGGREGATION_TYPE'] == 'School']
# Out:
# /home/mango/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# The function of schoolZip is to give the school district their own zip code. We will perform a join using District name as key. The issue is not all names are a 1 to 1 match. Some names have a slight variance. The frequency of these variances is low enough for me to manually change the name of the original data set to fix these abnormalities.

# %%
#FROM THE IRS I WAS ABLE TO FIND INCOME BY ZIP CODE TO HELP UNDESTAND EACH AREAS INCOME

incomeByZip16 = pd.read_csv('INCOME_DATA/16zpallnoagi.csv')
incomeByZip15 = pd.read_csv('INCOME_DATA/15zpallnoagi.csv')

# %%
incomeByZip16.head()
# Out:
#    STATEFIPS STATE  ZIPCODE  AGI_STUB       N1   MARS1   MARS2   MARS4  \
# 0          1    AL        0         0  2016530  825680  748830  402320
# 1          1    AL    35004         0     5210    2150    2140     830
# 2          1    AL    35005         0     3100    1340     890     830
# 3          1    AL    35006         0     1200     430     600     170
# 4          1    AL    35007         0    11940    4770    5140    1750
#
#       PREP       N2   ...      N10300    A10300  N85530  A85530  N85300  \
# 0  1140180  4065690   ...     1458270  14219765   23560   40254   28280
# 1     2470    10510   ...        4140     28671       0       0      30
# 2     1740     6020   ...        2180      9262       0       0       0
# 3      790     2560   ...         910      4982       0       0       0
# 4     5450    24950   ...        9340     75822      90      79      90
#
#    A85300  N11901   A11901   N11902   A11902
# 0   89091  358370  1683323  1583690  4690385
# 1      20     930     3022     4130    11001
# 2       0     430      860     2600     7364
# 3       0     180      315     1010     2873
# 4      83    2590     9648     8950    23317
#
# [5 rows x 147 columns]

# %%
grad2015.head()
# Out:
#   REPORT_SCHOOL_YEAR  AGGREGATION_INDEX AGGREGATION_TYPE  AGGREGATION_CODE  \
# 0            2014-15                  0        Statewide                 0
# 1            2014-15                  0        Statewide                 0
# 2            2014-15                  0        Statewide                 0
# 3            2014-15                  0        Statewide                 0
# 4            2014-15                  0        Statewide                 0
#
#              AGGREGATION_NAME  LEA_BEDS LEA_NAME  NRC_CODE NRC_DESC  \
# 0  All Districts and Charters       NaN      NaN       NaN      NaN
# 1  All Districts and Charters       NaN      NaN       NaN      NaN
# 2  All Districts and Charters       NaN      NaN       NaN      NaN
# 3  All Districts and Charters       NaN      NaN       NaN      NaN
# 4  All Districts and Charters       NaN      NaN       NaN      NaN
#
#    COUNTY_CODE     ...      REG_ADV_CNT  REG_ADV_PCT  \
# 0          NaN     ...            67250          31%
# 1          NaN     ...            36471          34%
# 2          NaN     ...            30779          28%
# 3          NaN     ...              182          17%
# 4          NaN     ...             3932          10%
#
#    NON_DIPLOMA_CREDENTIAL_CNT NON_DIPLOMA_CREDENTIAL_PCT  STILL_ENR_CNT  \
# 0                        3339                         2%           7304
# 1                        1186                         1%           3020
# 2                        2153                         2%           4284
# 3                          27                         2%             40
# 4                         900                         2%           2394
#
#    STILL_ENR_PCT GED_CNT  GED_PCT DROPOUT_CNT  DROPOUT_PCT
# 0             3%    2001       1%       24284          11%
# 1             3%     769       1%       10329          10%
# 2             4%    1232       1%       13955          13%
# 3             4%      25       2%         231          21%
# 4             6%     476       1%        7080          17%
#
# [5 rows x 36 columns]

# %% [markdown]
# Above this cell one can see that the data contains different aggregated values from statewide, district, individual school, county, etc... This means a lot of information is present within the data set. The only thing is I only require 1 aggregation type and that is the district aggregation. So below I took it upon myself to retrieve the aggregation type "District" from the data frame.

# %%
grad2015 = grad2015.loc[grad2015['AGGREGATION_TYPE'] == 'District']
grad2016 = grad2016.loc[grad2016['AGGREGATION_TYPE'] == 'District']

# %% [markdown]
# The data I received from the IRS contains not only the data from new york but the data of all of United States. Naturally, I took out the NY rows and replaced the unwanted data from other states.

# %%
# df.loc[df['column_name'] == some_value]
incomeByZip16 = incomeByZip16.loc[incomeByZip16['STATE']== "NY"]
incomeByZip15 = incomeByZip15.loc[incomeByZip15['STATE']== "NY"]

# %%
schoolZip.head()
# Out:
#    NCES LEA ID      State ID                            District Name  \
# 0      3602300  6.604130e+11        ABBOTT UNION FREE SCHOOL DISTRICT
# 1      3601001  3.207009e+11       ACADEMIC LEADERSHIP CHARTER SCHOOL
# 2      3600997  2.802019e+11                   ACADEMY CHARTER SCHOOL
# 3      3600129  1.010086e+10       ACHIEVEMENT ACADEMY CHARTER SCHOOL
# 4      3601028  3.316009e+11  ACHIEVEMENT FIRST APOLLO CHARTER SCHOOL
#
#   Mailing Address       City State  Zip Code  Zip +4     Telephone  \
# 0  100 N BROADWAY  IRVINGTON    NY     10533  1254.0  9.145917e+09
# 1  677 E 141ST ST      BRONX    NY     10454     NaN  7.185854e+09
# 2   94 FULTON AVE  HEMPSTEAD    NY     11550     NaN  5.164082e+09
# 3    42 S DOVE ST     ALBANY    NY     12202     NaN  5.185332e+09
# 4  350 LINWOOD ST   BROOKLYN    NY     11208     NaN  7.182353e+09
#
#   Locale codes of schools in the LEA      ...       \
# 0                                  3      ...
# 1                                  1      ...
# 2                                  3      ...
# 3                                  2      ...
# 4                                  1      ...
#
#   FY 2011 Title V allocation amount - PLEASE LEAVE BLANK SRSA rural eligible  \
# 0                                                NaN                       0
# 1                                                NaN                       0
# 2                                                NaN                       0
# 3                                                NaN                       0
# 4                                                NaN                       0
#
#    SRSA Small Eligible SRSA Rural Eligible SRSA Small Check SRSA eligible  \
# 0                    1                   0                0             -
# 1                    1                   0                0             -
# 2                    1                   0                0             -
# 3                    1                   0                0             -
# 4                    1                   0                0             -
#
#    RLIS rural eligible  RLIS pov. Eligible Initial RLIS eligible RLIS eligible
# 0                    0                   0                     0             -
# 1                    0                   0                     0             -
# 2                    0                   0                     0             -
# 3                    0                   0                     0             -
# 4                    0                   0                     0             -
#
# [5 rows x 32 columns]

# %% [markdown]
# There are a lot of columns in these data sets. Many of which are not helpful at the time being, especially for my purposes. That being said I took it upon myself to create new data frames but this time with only the data that I foresee myself using. However, if in the future I require more columns, I can easily insert them right here.

# %%
cincomeByZip16  = pd.DataFrame({
    "Zip Code": incomeByZip16["ZIPCODE"]
#     "Dependents" : incomeByZip16["NUMDEP"],
#     "Adjust Gross Income" : incomeByZip16["A02650"],
#     "Salaries and Wage" : incomeByZip16["A00200"],
#     "Range": incomeByZip16['AGI_STUB']
})

cincomeByZip15  = pd.DataFrame({
    "Zip Code": incomeByZip15["ZIPCODE"]
#     "Dependents" : incomeByZip15["NUMDEP"],
#     "Adjust Gross Income" : incomeByZip15["A02650"],
#     "Salaries and Wage" : incomeByZip15["A00200"],
#     "Range": incomeByZip16['AGI_STUB']
})

cdistrictGrad2016 = pd.DataFrame({
    "District Name" : grad2016["AGGREGATION_NAME"],
    "SUBGROUP_NAME": grad2016["SUBGROUP_NAME"]
#     "ENROLL_CNT": grad2016["ENROLL_CNT"],
#     "GRAD_CNT": grad2016["GRAD_CNT"],
#     "GRAD_PCT": grad2016["GRAD_PCT"],
#     "MEMBERSHIP_DESC" : grad2016["MEMBERSHIP_DESC"]
})

cdistrictGrad2015 = pd.DataFrame({
    "District Name" : grad2015["AGGREGATION_NAME"],
#     "SUBGROUP_NAME": grad2015["SUBGROUP_NAME"]
#     "ENROLL_CNT": grad2015["ENROLL_CNT"],
#     "GRAD_CNT": grad2015["GRAD_CNT"],
#     "GRAD_PCT": grad2015["GRAD_PCT"],
#     "MEMBERSHIP_DESC" : grad2015["MEMBERSHIP_DESC"]
})

cschoolZip = pd.DataFrame({
    "District Name":schoolZip["District Name"],
    "Zip Code":schoolZip["Zip Code"],
    "Zip +4":schoolZip["Zip +4"]
})

population16 = pd.DataFrame({
    "Zip Code": population["zip_code"],
    "pop": population["y-2016"]
})
population15 = pd.DataFrame({
    "Zip Code": population["zip_code"],
    "pop": population["y-2016"]
})

# %% [markdown]
# Finally I join the data sets. To join the school zip code DF and graduation DF I used District Name. As for income, I used zip code as my join condition. I usually output CSVs in order to look at it in excel. It helps me visualize the data map.

# %%
data = cdistrictGrad2016.join(cschoolZip.set_index('District Name'), on='District Name')
data = data.join(cincomeByZip16.set_index('Zip Code'), on='Zip Code')
data = data.join(population16.set_index('Zip Code'), on = 'Zip Code')
data = cityZip.join(data.set_index('Zip Code'),on = 'Zip Code')
data = data.dropna(subset=["District Name"])

data.to_csv('testOutput/out.csv')

# %%
data
# Out:
#     Zip Code                       District Name  \
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# 1      14202        BUFFALO CITY SCHOOL DISTRICT
# ..       ...                                 ...
# 27     14228  SWEET HOME CENTRAL SCHOOL DISTRICT
# 27     14228  SWEET HOME CENTRAL SCHOOL DISTRICT
# 27     14228  SWEET HOME CENTRAL SCHOOL DISTRICT
# 27     14228  SWEET HOME CENTRAL SCHOOL DISTRICT
# 27     14228  SWEET HOME CENTRAL SCHOOL DISTRICT
# 27     14228  SWEET HOME CENTRAL SCHOOL DISTRICT
# 27     14228  SWEET HOME CENTRAL SCHOOL DISTRICT
# 27     14228  SWEET HOME CENTRAL SCHOOL DISTRICT
# 27     14228  SWEET HOME CENTRAL SCHOOL DISTRICT
# 27     14228  SWEET HOME CENTRAL SCHOOL DISTRICT
# 27     14228  SWEET HOME CENTRAL SCHOOL DISTRICT
# 27     14228  SWEET HOME CENTRAL SCHOOL DISTRICT
# 27        Economically Disadvantaged  3399.0  21533.0
# 27    Not Economically Disadvantaged  3399.0  21533.0
# 27                       Not Migrant  3399.0  21533.0
# 27                      All Students  3399.0  21533.0
# 27                            Female  3399.0  21533.0
# 27                              Male  3399.0  21533.0
# 27         Black or African American  3399.0  21533.0
# 27                Hispanic or Latino  3399.0  21533.0
# 27         Asian or Pacific Islander  3399.0  21533.0
# 27                             White  3399.0  21533.0
# 27                       Multiracial  3399.0  21533.0
# 27        General Education Students  3399.0  21533.0
# 27        Students with Disabilities  3399.0  21533.0
# 27     Non-English Language Learners  3399.0  21533.0
# 27         English Language Learners  3399.0  21533.0
# 27        Economically Disadvantaged  3399.0  21533.0
# 27    Not Economically Disadvantaged  3399.0  21533.0
# 27                       Not Migrant  3399.0  21533.0
#
# [780 rows x 5 columns]

# %%
data2010Cohort = data.loc[data['MEMBERSHIP_DESC']== "2010 Total Cohort - 6 Year Outcome"]
data2011Cohort = data.loc[data['MEMBERSHIP_DESC']== "2011 Total Cohort - 5 Year Outcome"]
data2012Cohort = data.loc[data['MEMBERSHIP_DESC']== "2012 Total Cohort - 4 Year Outcome"]
data2012nAugCohort = data.loc[data['MEMBERSHIP_DESC']== "2012 Total Cohort - 4 Year Outcome - August 2016"]

data2010Cohort.to_csv('MAIN_DATA/2016/Cohort6y.csv')
data2011Cohort.to_csv('MAIN_DATA/2016/Cohort5y.csv')
data2012Cohort.to_csv('MAIN_DATA/2016/Cohort4y.csv')
data2012nAugCohort.to_csv('MAIN_DATA/2016/Cohort4ynAug.csv')

# %% [markdown]
# I used this to check if there are any empty zip codes that did not map. Previously, I had the following result
#
#
# ![alt text](Empty Cell.png "test")
#
# After finding the empty cellss i went through the data manually and found the zip codes for all those districts (naming descrepency was the issue).

# %%
data['Zip Code'].dropna
data['Zip Code'].fillna(0,inplace=True)
(data.loc[data['Zip Code']== 0])['District Name'].unique().tolist()
# Out:
# []

# %% [markdown]
# ### REFERENCE
#
# “NEW YORK STATE EDUCATION AT A GLANCE.” NYSED Data Site, Ney York State, data.nysed.gov/downloads.php. Accessed: Oct/27th/2018
#
# “Individual Income Tax Statistics.” Internal Revenue Service, Federal GOvernment, www.irs.gov/statistics/soi-tax-stats-individual-income-tax-statistics-zip-code-data-soi. Accessed: Oct/27th/2018
#
# “U.S. Department of Education.” SRSA Eligibility Spreadsheets for Fiscal Year 2012/School Year 2012-2013, www2.ed.gov/programs/reapsrsa/eligible12/index.html. Accessed: Nov/1/2018

# %%
data2 = cdistrictGrad2015.join(cschoolZip.set_index('District Name'), on='District Name')
data2 = data2.join(cincomeByZip15.set_index('Zip Code'), on='Zip Code')

data2 = data2.join(population15.set_index('Zip Code'), on = 'Zip Code')

data2.to_csv('testOutput/out2.csv')

# %%
data2010Cohort = data2.loc[data2['MEMBERSHIP_DESC']== "2009 Total Cohort - 6 Year Outcome"]
data2011Cohort = data2.loc[data2['MEMBERSHIP_DESC']== "2010 Total Cohort - 5 Year Outcome"]
data2012Cohort = data2.loc[data2['MEMBERSHIP_DESC']== "2011 Total Cohort - 4 Year Outcome"]
data2012nAugCohort = data2.loc[data2['MEMBERSHIP_DESC']== "2011 Total Cohort - 4 Year Outcome - August 2015"]

data2010Cohort.to_csv('MAIN_DATA/2015/Cohort6y.csv')
data2011Cohort.to_csv('MAIN_DATA/2015/Cohort5y.csv')
data2012Cohort.to_csv('MAIN_DATA/2015/Cohort4y.csv')
data2012nAugCohort.to_csv('MAIN_DATA/2015/Cohort4ynAug.csv')

# %%
data2012nAugCohort
# Out:
#                                       District Name  \
# 692                     ALBANY CITY SCHOOL DISTRICT
# 693                     ALBANY CITY SCHOOL DISTRICT
# 694                     ALBANY CITY SCHOOL DISTRICT
# 695                     ALBANY CITY SCHOOL DISTRICT
# 696                     ALBANY CITY SCHOOL DISTRICT
# 697                     ALBANY CITY SCHOOL DISTRICT
# 698                     ALBANY CITY SCHOOL DISTRICT
# 699                     ALBANY CITY SCHOOL DISTRICT
# 700                     ALBANY CITY SCHOOL DISTRICT
# 701                     ALBANY CITY SCHOOL DISTRICT
# 702                     ALBANY CITY SCHOOL DISTRICT
# 703                     ALBANY CITY SCHOOL DISTRICT
# 704                     ALBANY CITY SCHOOL DISTRICT
# 705                     ALBANY CITY SCHOOL DISTRICT
# 706                     ALBANY CITY SCHOOL DISTRICT
# 707                     ALBANY CITY SCHOOL DISTRICT
# 708                     ALBANY CITY SCHOOL DISTRICT
# 908     BERNE-KNOX-WESTERLO CENTRAL SCHOOL DISTRICT
# 909     BERNE-KNOX-WESTERLO CENTRAL SCHOOL DISTRICT
# 910     BERNE-KNOX-WESTERLO CENTRAL SCHOOL DISTRICT
# 911     BERNE-KNOX-WESTERLO CENTRAL SCHOOL DISTRICT
# 912     BERNE-KNOX-WESTERLO CENTRAL SCHOOL DISTRICT
# 913     BERNE-KNOX-WESTERLO CENTRAL SCHOOL DISTRICT
# 914     BERNE-KNOX-WESTERLO CENTRAL SCHOOL DISTRICT
# 915     BERNE-KNOX-WESTERLO CENTRAL SCHOOL DISTRICT
# 916     BERNE-KNOX-WESTERLO CENTRAL SCHOOL DISTRICT
# 917     BERNE-KNOX-WESTERLO CENTRAL SCHOOL DISTRICT
# 918     BERNE-KNOX-WESTERLO CENTRAL SCHOOL DISTRICT
# 919     BERNE-KNOX-WESTERLO CENTRAL SCHOOL DISTRICT
# 920     BERNE-KNOX-WESTERLO CENTRAL SCHOOL DISTRICT
# ...                                             ...
# 111994               WARSAW CENTRAL SCHOOL DISTRICT
# 111995               WARSAW CENTRAL SCHOOL DISTRICT
# 111996               WARSAW CENTRAL SCHOOL DISTRICT
# 111997               WARSAW CENTRAL SCHOOL DISTRICT
# 112152             PENN YAN CENTRAL SCHOOL DISTRICT
# 112153             PENN YAN CENTRAL SCHOOL DISTRICT
# 112154             PENN YAN CENTRAL SCHOOL DISTRICT
# 112155             PENN YAN CENTRAL SCHOOL DISTRICT
# 112156             PENN YAN CENTRAL SCHOOL DISTRICT
